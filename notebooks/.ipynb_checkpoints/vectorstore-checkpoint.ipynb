# %%
import sys
from pathlib import Path
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

PROJECT_ROOT = Path(r"E:/GenAi/project/Rag_cloud_platforms")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import src
print("src loaded from:", src.__file__)

from src.vectorstore import get_retriever
# Out:
# src loaded from: E:\GenAi\project\Rag_cloud_platforms\src\__init__.py

# %%
retriever = get_retriever(where={"provider": "aws"}, k=5)

docs = retriever.invoke("What is IAM in AWS?")

print("Found:", len(docs))
for i, d in enumerate(docs, 1):
    print(f"\n--- Doc {i} ---")
    print(d.metadata)
    print(d.page_content[:300])
# Out:
# Found: 5
#
# --- Doc 1 ---
# {'doc_id': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/introduction.html', 'title': 'What is IAM?', 'url': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/introduction.html', 'provider': 'aws', 'source_type': 'web', 'chunk_index': 0, 'category': 'service_fundamentals'}
# What is IAM? AWS Identity and Access Management (IAM) is a web service that helps you securely control access to AWS resources. With IAM, you can manage permissions that control which AWS resources users can access. You use IAM to control who is authenticated (signed in) and authorized (has permissi
#
# --- Doc 2 ---
# {'url': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/introduction.html', 'category': 'service_fundamentals', 'source_type': 'web', 'title': 'What is IAM?', 'provider': 'aws', 'doc_id': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/introduction.html', 'chunk_index': 1}
# ice, the request for authorization is sent to that service and it looks to see if your identity is on the list of authorized users, what policies are being enforced to control the level of access granted, and any other policies that might be in effect. Authorization requests can be made by principal
#
# --- Doc 3 ---
# {'title': 'AWS Analytics Reference Architecture', 'source_type': 'github', 'doc_id': 'aws-analytics-reference-architecture/core/API.md', 'provider': 'aws', 'chunk_index': 265, 'url': '', 'category': 'unknown'}
# "#aws-analytics-reference-architecture.NotebookPlatformProps.property.eksNamespace">eksNamespace</a></code> | <code>string</code> | the namespace where to deploy the EMR Virtual Cluster. | | <code><a href="#aws-analytics-reference-architecture.NotebookPlatformProps.property.idpArn">idpArn</a></code>
#
# --- Doc 4 ---
# {'category': 'security', 'source_type': 'web', 'chunk_index': 4, 'provider': 'aws', 'title': 'Security best practices in IAM', 'doc_id': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/best-practices.html', 'url': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/best-practices.html'}
# livers temporary AWS credentials to your Amazon ECS tasks running on those compute resources. Amazon Elastic Container Service (Amazon ECS) Anywhere lets you run Amazon ECS tasks on your own compute resources, and delivers temporary AWS credentials to your Amazon ECS tasks running on those compute r
#
# --- Doc 5 ---
# {'category': 'security', 'doc_id': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/best-practices.html', 'provider': 'aws', 'source_type': 'web', 'title': 'Security best practices in IAM', 'chunk_index': 5, 'url': 'https://docs.aws.amazon.com/IAM/latest/UserGuide/best-practices.html'}
# entials and device-generated response are required to complete the sign-in process. For more information, see AWS Multi-factor authentication in IAM . If you use IAM Identity Center for centralized access management for human users, you can use the IAM Identity Center MFA capabilities when your iden

# %%
import sys
print(sys.path)
# Out:
# ['E:\\GenAi\\project\\Rag_cloud_platforms', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\python311.zip', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\DLLs', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\Lib', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env', '', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\Lib\\site-packages', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\Lib\\site-packages\\win32', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Hp\\anaconda3\\envs\\rag_env\\Lib\\site-packages\\Pythonwin']
