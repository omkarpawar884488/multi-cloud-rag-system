# %%
from pathlib import Path
import json
import chromadb
from sentence_transformers import SentenceTransformer

# %%
def sanitize(v):
    return "" if v is None else v

# %%
BASE_DIR = Path(r"E:/GenAi/project/Rag_cloud_platforms")
chunks_path = BASE_DIR / "data/processed/chunks/chunks.jsonl"

# %%
chroma_dir = BASE_DIR / "data/vector_db/chroma"
chroma_dir.mkdir(parents=True, exist_ok=True)

client = chromadb.PersistentClient(path=str(chroma_dir))
collection = client.get_or_create_collection("cloud_rag_chunks")

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

ids, docs, metas = [], [], []
batch = 64

with chunks_path.open("r", encoding="utf-8") as f:
    for line in f:
        ch = json.loads(line)
        ids.append(ch["chunk_id"])
        docs.append(ch["chunk_text"])
        metas.append({
            "doc_id": sanitize(ch["doc_id"]),
            "provider": sanitize(ch["provider"]),
            "category": sanitize(ch["category"]),
            "source_type": sanitize(ch["source_type"]),
            "title": sanitize(ch["title"]),
            "url": sanitize(ch["url"]),
            "chunk_index": ch["chunk_index"],
        })
        if len(ids) >= batch:
            emb = model.encode(docs, show_progress_bar=False).tolist()
            #collection.add(ids=ids, documents=docs, metadatas=metas, embeddings=emb)
            collection.upsert(ids=ids, documents=docs, metadatas=metas, embeddings=emb)
            ids, docs, metas = [], [], []

if ids:
    emb = model.encode(docs, show_progress_bar=False).tolist()
    #collection.add(ids=ids, documents=docs, metadatas=metas, embeddings=emb)
    collection.upsert(ids=ids, documents=docs, metadatas=metas, embeddings=emb)


print("Stored in chroma:", chroma_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 27
#      17 metas.append({
#      18     "doc_id": sanitize(ch["doc_id"]),
#      19     "provider": sanitize(ch["provider"]),
#    (...)     24     "chunk_index": ch["chunk_index"],
#      25 })
#      26 if len(ids) >= batch:
# ---> 27     emb = model.encode(docs, show_progress_bar=False).tolist()
#      28     collection.add(ids=ids, documents=docs, metadatas=metas, embeddings=emb)
#      29     #collection.upsert(ids=ids, documents=docs, metadatas=metas, embeddings=emb)
#
# File ~\anaconda3\envs\rag_env\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# ...

# %%
BASE_DIR = Path(r"E:/GenAi/project/Rag_cloud_platforms")
chunks_path = BASE_DIR / "data/processed/chunks/chunks.jsonl"

chroma_dir = BASE_DIR / "data/vector_db/chroma"
chroma_dir.mkdir(parents=True, exist_ok=True)

client = chromadb.PersistentClient(path=str(chroma_dir))
collection = client.get_or_create_collection("cloud_rag_chunks")



print("Count in collection:", collection.count())
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1431
# Count in collection: 65994

# %%
hasattr(collection, "upsert")
# Out:
# True

# %%
#Count in collection: 65994
